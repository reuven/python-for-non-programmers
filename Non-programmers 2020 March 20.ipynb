# %%
# this is a comment!

print("Hello, world!!!!!")    # shift + enter to execute the cell
# Out:
# Hello, world!!!!!

# %%
# jupyter

# %%
print("Hello, Reuven!")
# Out:
# Hello, Reuven!

# %%
print("Reuven")
# Out:
# Reuven

# %%
# to create a new varible, assign a value to it
name = 'Reuven'  # shift + enter executes + creates a new one

# %%
print('Reuven')
# Out:
# Reuven

# %%
name = 'someone else'

# %%
print(name)
# Out:
# someone else

# %%
name = 'whatever you want'
print(name)
# Out:
# whatever you want

# %%
x = 100
print(x)
# Out:
# 100

# %%
x = 100
y = 200

print(x + y)  # shift + enter to execute the cell
# Out:
# 300

# %%
print(x + x + y + y)
# Out:
# 600

# %%
x + y
# Out:
# 300

# %%
x
# Out:
# 100

# %%
y
# Out:
# 200

# %%
x  # expression by itself -- not printed -- not last line -- ignored
y  # expression by itself -- on the last line -- we get its value
# Out:
# 200

# %%
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-ded5ba42480f> in <module>
# ----> 1 s
#
# NameError: name 's' is not defined

# %%
x = 100
y = 200

x + y
# Out:
# 300

# %%
x = '100'
y = '200'

x + y
# Out:
# '100200'

# %%
x = 100
y = '200'

x + y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-8e796e1c7a7a> in <module>
#       2 y = '200'
#       3
# ----> 4 x + y
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
name = 'Reuven'
print(name)
# Out:
# Reuven

# %%
print('name')
# Out:
# name

# %%
name = 'Reuven'
print('Hello, ' + name)
# Out:
# Hello, Reuven

# %%
print('Hello,' + name)
# Out:
# Hello,Reuven

# %%
print('Hello,    ' + name)
# Out:
# Hello,    Reuven

# %%
100+200
# Out:
# 300

# %%
name = input('Enter your name: ')
print('Hello, ' + name)
# Out:
# Enter your name: Reuven
# Hello, Reuven

# %%
# VARIABLE = VALUE

input('Enter your name: ') = name
# Out:
#   File "<ipython-input-33-e2c50ee231f1>", line 3
#     input('Enter your name: ') = name
#                                      ^
# SyntaxError: can't assign to function call

# %%
x = 100

# %%
x = 100 + 200

# %%
x = 100

# %%
x = 'abcd'

# %%
print(x)
# Out:
# abcd

# %%
type(x)
# Out:
# str

# %%
x = 100
type(x)
# Out:
# int

# %%
x = 100

# %%
x = 200

# %%
# memory leak

# %%
x = 100
print(x)
print(x)

x = 200
print(x)
print(x)
